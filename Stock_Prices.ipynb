# %% [markdown]
# <a href="https://colab.research.google.com/github/Finardiprof/Python/blob/main/Stock_Prices.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
Tesla = yf.download("TSLA", period="12mo")
print(Tesla.Close)
import matplotlib.pyplot as plt
plt.plot(Tesla.Close)
plt.plot(Tesla.High)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Date
# 2022-10-24    211.250000
# 2022-10-25    222.419998
# 2022-10-26    224.639999
# 2022-10-27    225.089996
# 2022-10-28    228.520004
#                  ...
# 2023-10-18    242.679993
# 2023-10-19    220.110001
# 2023-10-20    211.990005
# 2023-10-23    212.080002
# 2023-10-24    216.000000
# Name: Close, Length: 252, dtype: float64
