# %% [markdown]
# <a href="https://colab.research.google.com/github/Finardiprof/Python/blob/main/Copia_di_Portafoglio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

portfolio = ["AAPL", "GOOGL", "TSLA", "MSFT", "AMZN"]
portfolio_data = yf.download(portfolio, start="2023-10-01", end="2023-12-31")
# Calculate daily returns for each stock
daily_returns = portfolio_data['Adj Close'].pct_change()

# Calculate portfolio value based on the number of shares you own
shares = [10, 5, 3, 8, 2]  # Replace with your own share quantities
portfolio_value = (portfolio_data['Adj Close'] * shares).sum(axis=1)

# Visualize the portfolio value
portfolio_value.plot(figsize=(10, 6), title="Portfolio Value")
plt.show()
daily_returns.plot(figsize=(10, 6), title="Portfolio Value")
plt.show()
# Out:
# [*********************100%%**********************]  5 of 5 completed
