# %% [markdown]
# <a href="https://colab.research.google.com/github/Finardiprof/Python/blob/main/Tipi_di_Dato.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Inserisci diverse variabili ed esplora i vari tipi di dato
#
# NOTA: La funzione type() restituisce il tipo di dato di una variabile.

# %%
# esempio
a = 3
print(type(a))
# Out:
# <class 'int'>

# %%
[] # inserisici il codice qui

# %% [markdown]
# ## ESEMPI:

# %% [markdown]
# ![immagine_2023-10-25_094144015.png](data:image/png;base64,...)

# %% [markdown]
# ![Tipi di dato.png](data:image/png;base64,...)
